# %%
# How the cross validation works behind and how it will look in dataframe is this code:




import pandas as pd
indexes = [f"h_{i}" for i in range(1,37)]
col1 = [f"combination_1_accuracy_{i}"for i in range(1,37)]
col2 = [f"combination_2_accuracy_{i}"for i in range(1,37)]
col3 = [f"combination_3_accuracy_{i}"for i in range(1,37)]
col4 = [f"combination_4_accuracy_{i}"for i in range(1,37)]
col5 = [f"average_accuracy_{i}"for i in range(1,37)]
cols = ['c1','c2','c3','c4','Avg_acc']
pd.DataFrame(zip(col1,col2,col3,col4,col5),index=indexes,columns=cols)
# Out:
#                              c1                         c2  \
# h_1    combination_1_accuracy_1   combination_2_accuracy_1
# h_2    combination_1_accuracy_2   combination_2_accuracy_2
# h_3    combination_1_accuracy_3   combination_2_accuracy_3
# h_4    combination_1_accuracy_4   combination_2_accuracy_4
# h_5    combination_1_accuracy_5   combination_2_accuracy_5
# h_6    combination_1_accuracy_6   combination_2_accuracy_6
# h_7    combination_1_accuracy_7   combination_2_accuracy_7
# h_8    combination_1_accuracy_8   combination_2_accuracy_8
# h_9    combination_1_accuracy_9   combination_2_accuracy_9
# h_10  combination_1_accuracy_10  combination_2_accuracy_10
# h_11  combination_1_accuracy_11  combination_2_accuracy_11
# h_12  combination_1_accuracy_12  combination_2_accuracy_12
# h_13  combination_1_accuracy_13  combination_2_accuracy_13
# h_14  combination_1_accuracy_14  combination_2_accuracy_14
# h_15  combination_1_accuracy_15  combination_2_accuracy_15
# ...
